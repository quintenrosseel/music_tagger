# %% [markdown]
# # Config

# %%
from pyrekordbox import show_config

show_config()
# Out:
# Pioneer:
#    app_dir =      /Users/quintenrosseel/Library/Application Support/Pioneer
#    install_dir =  /Applications
# Rekordbox 5:
# Rekordbox 6:
# Rekordbox 7:
#    app_dir =      /Users/quintenrosseel/Library/Application Support/Pioneer/rekordbox6
#    db_dir =       /Users/quintenrosseel/Library/Pioneer/rekordbox
#    db_path =      /Users/quintenrosseel/Library/Pioneer/rekordbox/master.db
#    install_dir =  /Applications/rekordbox 7
#    version =      7
